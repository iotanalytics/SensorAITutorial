# %% [markdown]
# <a href="https://colab.research.google.com/github/iotanalytics/IoTTutorial/blob/main/code/detection_and_segmentation/Changing_point_detection_with_ruptures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Changing point detection with ruptures

# %% [markdown]
# Ruptures is a Python library for off-line change point detection. This package provides methods for the analysis and segmentation of non-stationary signals. Implemented algorithms include exact and approximate detection for various parametric and non-parametric *models*
#
# C. Truong, L. Oudre, N. Vayatis. Selective review of offline change point detection methods. Signal Processing, 167:107299, 2020.

# %%
# !pip install ruptures
# Out:
# ...
#      |████████████████████████████████| 918 kB 4.9 MB/s
# ...

# %%
import matplotlib.pyplot as plt
# https://charles.doffy.net/ruptures/build/html/index.html
import ruptures as rpt

# detection
bkps = [300,400]
algo = rpt.Pelt(model="rbf").fit(data)
result = algo.predict(5)

# display
rpt.display(data, bkps, result)
plt.show()
